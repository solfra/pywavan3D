# %% [markdown]
# # Cube de données G353 7m+12m N2H+

# %%
# %pylab inline
from pywavan import fbm2d, powspec, fan_trans
from astropy.io import fits
import aplpy
from pywavan import subfits
from pywavan import nb_scale
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
HDU = fits.open("/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image.fits")
cube = HDU[0].data
header = HDU[0].header

# %%
cube.shape
# Out:
# (1, 139, 960, 960)

# %%
del header['CTYPE4']
del header['CRVAL4']
del header['CDELT4']
del header['CRPIX4']
del header['CUNIT4']
del header['NAXIS4']
del header['PC4_1']
del header['PC4_2']
del header['PC4_3']
del header['PC1_4']
del header['PC2_4']
del header['PC3_4']
del header['PC4_4']
header['NAXIS'] = 3

# %%
new_cube = []
for i in range(header['NAXIS3']) :
    new_cube.append(cube[0,i,:,:])

# %%
new_cube = np.array(new_cube)

# %%
new_cube.shape
# Out:
# (139, 960, 960)

# %%
fits.writeto("/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image2.fits",new_cube, header)

# %%
HDU = fits.open("/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image2.fits")
cube = HDU[0].data
header = HDU[0].header

# %%
cube.shape
# Out:
# (139, 960, 960)

# %%
fig_all = plt.figure(1, figsize=(15,15))
fig = aplpy.FITSFigure("/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image2.fits",figure=fig_all,slices=[50])
fig.show_colorscale(cmap='gray')
fig.add_colorbar()
fig.add_grid()
# Out:
# INFO: Auto-setting vmin to -5.641e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.033e-01 [aplpy.core]

# %% [markdown]
# ***
# # Cut du cube d'origine

# %%
input1 = '/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image2.fits'
output = '/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image_cut.fits'
coord = np.array([267,299,14,686,640,128])
subfits(input1,output,coord)
# Out:
# Dimensions 420 342 115

# %%
HDU = fits.open("/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image_cut.fits")
cube = HDU[0].data
header = HDU[0].header

# %%
fig_all = plt.figure(1, figsize=(15,15))
fig = aplpy.FITSFigure("/user/workdir/soldanof/ALMA/G353.41_B3_spw0_7M12M_n2hp.image_cut.fits",figure=fig_all,slices=[50])
fig.show_colorscale(cmap='gray')
fig.add_colorbar()
fig.add_grid()
# Out:
# INFO: Auto-setting vmin to -1.516e-01 [aplpy.core]
# INFO: Auto-setting vmax to  5.055e-01 [aplpy.core]

# %% [markdown]
# ***
# # Test de vérification de pywavan

# %%
cube.shape
# Out:
# (115, 342, 420)

# %%
reso = header ['CDELT2']*60
q = []
q= [2.0]*nb_scale((115, 500,600))

wt, S11a, wave_k, S1a, q =  fan_trans(cube[50,:,:], reso=reso, angular=False,q=q,apodize = 0.98,arrdim = np.array([500,600]))

#wt, S11a, wave_k, S1a, q =  fan_trans(cube[1,:,:], reso=reso, angular=False,q=q,apodize = 0.98)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 600 500
# 100%|██████████| 22/22 [00:17<00:00,  1.28it/s]

# %%
M = nb_scale((115, 500,600))

coherent = np.sum(wt[M:2*M,:,:],axis=0)
Gaussian = np.sum(wt[2*M:3*M,:,:],axis=0)

# %%
figure(figsize=(20,10))
subplot(1,2,1)
imshow(Gaussian.real,origin="lower")
title('Gaussian')
subplot(1,2,2)
imshow(coherent.real,origin="lower")
title('coherent')
# Out:
# Text(0.5, 1.0, 'coherent')

# %%
plt.plot(wave_k, S1a[0,:],label="tot")
plt.plot(wave_k, S1a[1,:],"x",label="ng")
plt.plot(wave_k, S1a[2,:],"o",label="g")
plt.xscale("log")
plt.yscale("log")
plt.legend()

# %% [markdown]
# ***
# # Pywavan sur tout le cube

# %%
reso = header ['CDELT2']*60
M = nb_scale((115, 500,600))
N = header['NAXIS3']

# %%
coherent_tot = []
gaussian_tot = []
s1a_tot_tot = []
s1a_tot_gau = []
s1a_tot_ng = []

for i in range(N) :
    q = []
    q= [2.0]*nb_scale((115, 500,600))
    print("data number",i)
    wt, S11a, wave_k, S1a, q =  fan_trans(cube[i,:,:], reso=reso, angular=False,q=q,apodize = 0.98,arrdim = np.array([500,600]))

    coherent = np.sum(wt[M:2*M,:,:],axis=0)
    Gaussian = np.sum(wt[2*M:3*M,:,:],axis=0) 
    
    coherent_tot.append( coherent )
    gaussian_tot.append( Gaussian )
    s1a_tot_tot.append( S1a[0,:] )
    s1a_tot_ng.append(S1a[1,:])
    s1a_tot_gau.append(S1a[2,:])

np.save("/user/workdir/soldanof/data/G353/coh.npy", coherent_tot)
np.save("/user/workdir/soldanof/data/G353/gau.npy", gaussian_tot)
np.save("/user/workdir/soldanof/data/G353/s1at.npy",s1a_tot_tot)
np.save("/user/workdir/soldanof/data/G353/s1ag.npy",s1a_tot_gau)
np.save("/user/workdir/soldanof/data/G353/s1ang.npy",s1a_tot_ng)
np.save("/user/workdir/soldanof/data/G353/wave_k.npy",wave_k)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 0
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 1
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 2
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 3
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 4
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 5
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 6
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 7
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 8
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 9
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 10
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 11
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 12
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 13
# 600 500
# ...
#   0%|          | 0/22 [00:00<?, ?it/s]
# data number 14
# ...

# %%
figure(figsize=(20,10))
im_g = np.load("/user/workdir/soldanof/data/G353/gau.npy")
im_ng = np.load("/user/workdir/soldanof/data/G353/coh.npy")

subplot(1,2,1)
imshow(im_g[90].real,origin="lower")
title('Gaussian')

subplot(1,2,2)
imshow(im_ng[90].real,origin="lower")
title('Coherent')
# Out:
# Text(0.5, 1.0, 'Coherent')

# %%
figure(figsize=(20,10))
t = np.load("/user/workdir/soldanof/data/G353/s1at.npy")
g = np.load("/user/workdir/soldanof/data/G353/s1ag.npy")
ng = np.load("/user/workdir/soldanof/data/G353/s1ang.npy")
wk = np.load("/user/workdir/soldanof/data/G353/wave_k.npy")
plt.plot(wk, t[95],label="tot")
plt.plot(wk, g[95],"o",label="g")
plt.plot(wk, ng[95],"x",label="ng")
plt.xscale("log")
plt.yscale("log")
plt.legend()
